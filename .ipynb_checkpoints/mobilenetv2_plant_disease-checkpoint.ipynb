# %% [markdown]
# ### Import Libraries

# %%
#Import Libraries
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Load Data

# %%
#Create Data Generators
train_dir = './data/train'
val_dir = './data/val'

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
)

val_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation sets
train_dataset = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_dataset = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 3724 images belonging to 5 classes.
# Found 784 images belonging to 5 classes.

# %% [markdown]
# ### Load Pretrained MobileNetV2

# %%
#Load Pretrained MobileNetV2
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze the base layers for feature extraction
for layer in base_model.layers:
    layer.trainable = False
# Out:
# 2025-11-20 09:40:43.915924: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2025-11-20 09:40:43.916156: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-11-20 09:40:43.916172: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-11-20 09:40:43.916507: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-11-20 09:40:43.916546: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Add Custom Layers for the Dataset

# %%
#Add Custom Layers for the Dataset
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)

# Adjust 'num_classes' to dataset
num_classes = train_dataset.num_classes
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# %% [markdown]
# ### Compile and Train

# %%
#Compile and Train
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10,
    verbose=1
)
# Out:
# Epoch 1/10
# 2025-11-20 09:40:55.537758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 24s 171ms/step - accuracy: 0.5599 - loss: 1.2944 - val_accuracy: 0.8367 - val_loss: 0.4672
# Epoch 2/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.8010 - loss: 0.5796 - val_accuracy: 0.8661 - val_loss: 0.3651
# Epoch 3/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.8257 - loss: 0.4855 - val_accuracy: 0.8776 - val_loss: 0.3353
# Epoch 4/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.8485 - loss: 0.4266 - val_accuracy: 0.8852 - val_loss: 0.3081
# Epoch 5/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.8563 - loss: 0.4160 - val_accuracy: 0.8890 - val_loss: 0.2946
# Epoch 6/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.8682 - loss: 0.3621 - val_accuracy: 0.8954 - val_loss: 0.2768
# Epoch 7/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 166ms/step - accuracy: 0.8652 - loss: 0.3654 - val_accuracy: 0.8980 - val_loss: 0.2697
# Epoch 8/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.8695 - loss: 0.3563 - val_accuracy: 0.8992 - val_loss: 0.2724
# Epoch 9/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 162ms/step - accuracy: 0.8751 - loss: 0.3528 - val_accuracy: 0.9043 - val_loss: 0.2612
# Epoch 10/10
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.8845 - loss: 0.3396 - val_accuracy: 0.9069 - val_loss: 0.2554

# %% [markdown]
# ### Fine-Tune

# %%
#Fine-Tune
for layer in base_model.layers[-30:]:
    layer.trainable = True

model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_fine = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=5,
    verbose=1
)
# Out:
# Epoch 1/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 26s 181ms/step - accuracy: 0.7900 - loss: 0.5609 - val_accuracy: 0.9082 - val_loss: 0.2564
# Epoch 2/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.8628 - loss: 0.3786 - val_accuracy: 0.9069 - val_loss: 0.2540
# Epoch 3/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 165ms/step - accuracy: 0.8673 - loss: 0.3552 - val_accuracy: 0.9094 - val_loss: 0.2504
# Epoch 4/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 165ms/step - accuracy: 0.8802 - loss: 0.3227 - val_accuracy: 0.9094 - val_loss: 0.2471
# Epoch 5/5
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 19s 165ms/step - accuracy: 0.8929 - loss: 0.2937 - val_accuracy: 0.9107 - val_loss: 0.2388

# %% [markdown]
# ### Save Model

# %%
model.save('./model/mobilenetv2_plant_disease.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# Evaluate the model on validation data
val_loss, val_acc = model.evaluate(val_dataset)
print(f"\n Validation Accuracy: {val_acc*100:.2f}%")
print(f" Validation Loss: {val_loss:.4f}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.9107 - loss: 0.2388
#
#  Validation Accuracy: 91.07%
#  Validation Loss: 0.2388

# %%
# Get predictions
y_true = val_dataset.classes
Y_pred = model.predict(val_dataset)
y_pred = np.argmax(Y_pred, axis=1)

# Reverse mapping (index → label)
class_labels = {v: k for k, v in train_dataset.class_indices.items()}
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step

# %%
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
plt.figure(figsize=(10, 8))
disp.plot(cmap='Blues', xticks_rotation=45, colorbar=False)
plt.title('Confusion Matrix')
plt.show()

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# Classification Report:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 print("Classification Report:\n")
# ----> 2 print(classification_report(y_true, y_pred, target_names=class_labels))
#
# File /opt/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File /opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:3001, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2999 else:
#    3000     longest_last_line_heading = "weighted avg"
# -> 3001     name_width = max(len(cn) for cn in target_names)
#    3002     width = max(name_width, len(longest_last_line_heading), digits)
#    3003     head_fmt = "{:>{width}s} " + " {:>9}" * len(headers)
#
# File /opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:3001, in <genexpr>(.0)
#    2999 else:
#    3000     longest_last_line_heading = "weighted avg"
# -> 3001     name_width = max(len(cn) for cn in target_names)
#    3002     width = max(name_width, len(longest_last_line_heading), digits)
#    3003     head_fmt = "{:>{width}s} " + " {:>9}" * len(headers)
#
# TypeError: object of type 'int' has no len()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# ----------------------------
# 1. Evaluate the model
# ----------------------------
val_loss, val_acc = model.evaluate(val_dataset)
print(f"\nValidation Accuracy: {val_acc*100:.2f}%")
print(f"Validation Loss: {val_loss:.4f}")

# ----------------------------
# 2. Predict on validation set
# ----------------------------
y_true = val_dataset.classes                   # Ground truth labels
Y_pred = model.predict(val_dataset)            # Prediction probabilities
y_pred = np.argmax(Y_pred, axis=1)             # Predicted class indexes

# ----------------------------
# 3. Prepare class labels
# ----------------------------
class_labels = {v: k for k, v in train_dataset.class_indices.items()}
label_names = [class_labels[i] for i in range(len(class_labels))]

# ----------------------------
# 4. Confusion Matrix
# ----------------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_names)
disp.plot(cmap='Blues', xticks_rotation=45, colorbar=False)
plt.title('Confusion Matrix')
plt.show()

# ----------------------------
# 5. Classification Report
# ----------------------------
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=label_names))
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.9107 - loss: 0.2388
#
# Validation Accuracy: 91.07%
# Validation Loss: 0.2388
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
# Classification Report:
#
#                 precision    recall  f1-score   support
#
#         Blight       0.25      0.25      0.25       206
#       Cob_Root       0.08      0.08      0.08        66
#    Common_Rust       0.32      0.30      0.31       261
# Gray_Leaf_Spot       0.12      0.14      0.13       101
#        Healthy       0.20      0.21      0.21       150
#
#       accuracy                           0.23       784
#      macro avg       0.19      0.19      0.19       784
#   weighted avg       0.23      0.23      0.23       784

# %% [markdown]
# ### Conclusion

# %% [markdown]
# In this practise model I used a pretrained mobilenetv2 & added a fine tuning which improve the model accuracy compare to earlier one.
#
# *** Note: mobilenet also lightweight, faster which suitable to use in mobile apps
